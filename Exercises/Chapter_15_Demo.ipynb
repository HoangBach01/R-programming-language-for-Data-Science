# %%
x = seq(-10, 10, by=.1)
y = dnorm(x, mean=0, sd=1)

plot(x, y)
# Out:
# plot without title

# %%
print(paste('Probability of 2 in distribution: ',round(dnorm(2, mean=0, sd=1)*100,1), '%'))
# Out:
# [1] "Probability of 2 in distribution:  5.4 %"

# %%
dnorm(160, mean=156, sd=4.6)
# Out:
# [1] 0.05942343

# %%
dnorm(2, mean=0, sd=1)
# Out:
# [1] 0.05399097

# %%
y = pnorm(x, mean=0, sd=1)
plot(x, y)
# Out:
# plot without title

# %%
pnorm(5, mean=0, sd=1)
# Out:
# [1] 0.9999997

# %%
x = seq(0, 1, by = 0.02)
y = qnorm(x, mean=0, sd=1)
plot(x, y)
# Out:
# plot without title

# %%
y = rnorm(50, mean=156, sd=4)
hist(y, main='Normal Distribution', breaks=10)
# Out:
# Plot with title “Normal Distribution”

# %%
x = seq(0, 50, by=1)
y = dbinom(x, 50, 0.5)
plot(x, y)
# Out:
# plot without title

# %%
dbinom(17, 50, 0.5)
# Out:
# [1] 0.00874623

# %%
p_x_25_less = pbinom(25, 50, 0.5)
p_x_25_less
# Out:
# [1] 0.5561376

# %%
p_x_25_more = 1- pbinom(24, 50, 0.5)
p_x_25_more
# Out:
# [1] 0.5561376

# %%
x = qbinom(0.25, 50, 0.5)
x
# Out:
# [1] 23

# %%
x = rbinom(8, 100, 1/6)
x
# Out:
# [1] 15 21 16 14 14 16 18 15

# %%
dbinom(2, 8, 0.3)
# Out:
# [1] 0.2964755

# %%
dbinom(7, 8, 0.3)
# Out:
# [1] 0.00122472

# %%
1 - pbinom(1, 8, 0.3)
# Out:
# [1] 0.7447017

# %%
1 - (dbinom(0, 8, 0.3) + dbinom(1, 8, 0.3))
# Out:
# [1] 0.7447017

# %%
1-pnorm(84, mean=72, sd=15.2)
# Out:
# [1] 0.2149176

# %%
v = c(1:100)
summary(v)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    1.00   25.75   50.50   50.50   75.25  100.00

# %%
library()

# %%
help(mean)

# %%
example(mean)
# Out:
# mean> x <- c(0:10, 50)
#
# mean> xm <- mean(x)
#
# mean> c(xm, mean(x, trim = 0.10))
# [1] 8.75 5.50

# %%
sum_even.fun = function(start, end) {
    sum = 0
    for (i in start:end) {
        if (i%%2 == 0) {
            sum = sum + i
        }
    }
    return (sum)
}

# %%
sum_even.fun(1,50)
# Out:
# [1] 650

# %%
# bmi.function = function(height, weight) {
#     bmi = weight / (height ^ 2)
#     return (bmi)
# }

# infer_bmi.function = function(bmi) {
#     if (bmi < 18.5) {result = 'Under weight'}
#     else if (bmi < 25) {result = 'Normal'}
#     else {result = 'Over weight'}
#     return (result)
# }

# %%
# https://drive.google.com/file/d/1NWFnZKkdEUwQHZtCUO_g30Xkhrr-uzBw/view?usp=sharing
system("gdown --id 1NWFnZKkdEUwQHZtCUO_g30Xkhrr-uzBw")
source("functions.R")
height = as.numeric(readline(prompt = 'Input height (m): '))
weight = as.numeric(readline(prompt = 'Input weight (kg): '))
bmi = bmi.function(height, weight)
result = infer_bmi.function(bmi)
print(paste('BMI:', round(bmi,2)))
print(paste('Result:', result))
# Out:
# Input height (m): 1.7
# Input weight (kg): 70
# [1] "BMI: 24.22"
# [1] "Result: Normal"
